# %%
from __future__ import (absolute_import, print_function,
                        division, unicode_literals)

# %%
from IPython.display import HTML

# %%
DEBUG = False  # when debugging is on, only run two notebooks

# %%
def report(nbs, rec):
    """Produce user-friendly report on notebook result."""
    report_tpl = """
    <h1>Fig. {fig_no}. {title}</h1>
    <div style="margin: 15">{thumb}</div>
    <hr>
    """
    
    error_tpl = """
    <h1>Notebook {} generated no valid plot.</h1>
    <hr>
    """
    
    try:
        return report_tpl.format(fig_no=rec.specs['fig_no'],
                                 title=rec.specs['title'],
                                 thumb=rec.specs['thumb'])
    except:
        return error_tpl.format(nbs)

# %% [markdown]
# # Notebook to run all others

# %% [markdown]
# This notebook runs all others in the folder. Its main use: to update the static website with new template features.

# %%
output = ''

nb_list = [4, 1] if DEBUG else [4, 1, 2, 3, 5, 6,
                                7, 9, 8, 11, 10, 12,
                                13, 15, 14, 16, 18, 17]

for nb in nb_list:
    rec = None  # clear away remnants of any previous notebook
    nbs = 'notebook_{}.ipynb'.format(str(nb).zfill(2))
    # %run $nbs
    output += report(nbs, rec)
    
HTML(output)
# Out:
# DF: <class 'pandas.core.frame.DataFrame'>
# caption: <type 'NoneType'>
# fig: <class 'plotly.graph_objs.graph_objs.Figure'>
# fig_no: <type 'numpy.int64'>
# filename: <type 'str'>
# plot_height: <type 'numpy.int64'>
# plot_width: <type 'numpy.int64'>
# record: <type 'dict'>
# ref_no: <type 'numpy.int64'>
# source_accessed: Accessed 28 March 2015
# source_label: World Economic Forum (WEF). The Global Gender Gap Report (2014)
# source_link: http://reports.weforum.org/global-gender-gap-report-2014/rankings/
# subtitle: Global Gender Gap for 47 Member States of the WHO European Region (2014)
# thumb: <img src="https://api.plot.ly/v2/files/gauden:515/image?image_name=block-thumb" alt="Gender gap in selected European countries">
# time_epoch: <type 'float'>
# time_human: <type 'str'>
# title: Gender gap in selected European countries
# url_embed: https://plot.ly/~gauden/515.embed
# url_svg: https://plot.ly/~gauden/515.svg
# x_label: <type 'NoneType'>
# y_label: Score (0=Inequality / 1=Equality)
#
# ¶ The former Yugoslav Republic of Macedonia (MKD is an abbreviation of the ISO).
# DF: <class 'pandas.core.frame.DataFrame'>
# caption: <type 'NoneType'>
# fig: <class 'plotly.graph_objs.graph_objs.Figure'>
# fig_no: <type 'numpy.int64'>
# filename: <type 'str'>
# plot_height: <type 'numpy.int64'>
# plot_width: <type 'numpy.int64'>
# record: <type 'dict'>
# ref_no: <type 'numpy.int64'>
# source_accessed: Accessed 28 March 2015
# source_label: WHO  Global health observatory.
# source_link: http://apps.who.int/gho/data/node.main.3?lang=en
# subtitle: Healthy life at birth and number of years spent in ill-health for women (2012)
# thumb: <img src="https://api.plot.ly/v2/files/gauden:511/image?image_name=block-thumb" alt="Beyond the mortality advantage">
# time_epoch: <type 'float'>
# time_human: <type 'str'>
# title: Beyond the mortality advantage
# url_embed: https://plot.ly/~gauden/511.embed
# url_svg: https://plot.ly/~gauden/511.svg
# x_label: Number of years
# y_label: Countries
#
# ¶ The former Yugoslav Republic of Macedonia (MKD is an abbreviation of the ISO).
# DF: <class 'pandas.core.frame.DataFrame'>
# caption: <type 'NoneType'>
# fig: <class 'plotly.graph_objs.graph_objs.Figure'>
# fig_no: <type 'numpy.int64'>
# filename: <type 'str'>
# plot_height: <type 'numpy.int64'>
# plot_width: <type 'numpy.int64'>
# record: <type 'dict'>
# ref_no: <type 'numpy.int64'>
# source_accessed: Accessed 10 July 2015
# source_label: WHO/Europe Health for All Database
# source_link: http://data.euro.who.int/hfadb/
# subtitle: Female life expectancy at birth (2013) by estimated GNI PPP$ per capita (2011)
# thumb: <img src="https://api.plot.ly/v2/files/gauden:513/image?image_name=block-thumb" alt="Female life expectancy by Gross National Income">
# time_epoch: <type 'float'>
# time_human: <type 'str'>
# title: Female life expectancy by Gross National Income
# url_embed: https://plot.ly/~gauden/513.embed
# url_svg: https://plot.ly/~gauden/513.svg
# x_label: GNI per capita (USD, at PPP)
# y_label: Female Life Expectancy (Years)
#
# DF: <class 'pandas.core.frame.DataFrame'>
# caption: <type 'NoneType'>
# fig: <class 'plotly.graph_objs.graph_objs.Figure'>
# fig_no: <type 'numpy.int64'>
# filename: <type 'str'>
# plot_height: <type 'numpy.int64'>
# plot_width: <type 'numpy.int64'>
# record: <type 'dict'>
# ref_no: <type 'numpy.int64'>
# source_accessed: Accessed 28 March 2015
# source_label: United Nations Development Programme (UNDP)
# source_link: http://hdr.undp.org/en/content/labour-force-participation-rate-female-male-ratio
# subtitle: Labour Force participation rate (%) for males and females (2000-2012)
# thumb: <img src="https://api.plot.ly/v2/files/gauden:517/image?image_name=block-thumb" alt="Do European countries maximize the education gain?">
# time_epoch: <type 'float'>
# time_human: <type 'str'>
# title: Do European countries maximize the education gain?
# url_embed: https://plot.ly/~gauden/517.embed
# url_svg: https://plot.ly/~gauden/517.svg
# x_label: Percentage
# y_label: <type 'NoneType'>
#
#
# DF: <class 'pandas.core.frame.DataFrame'>
# caption: This represents the difference between average gross hourly earnings of male paid employees and female paid employees as a percentage of gross hourly earnings of male paid employees.  The population consists of all paid employees in enterprises with 10 employees or more.
# fig: <class 'plotly.graph_objs.graph_objs.Figure'>
# fig_no: <type 'numpy.int64'>
# filename: <type 'str'>
# plot_height: <type 'numpy.int64'>
# plot_width: <type 'numpy.int64'>
# record: <type 'dict'>
# ref_no: <type 'numpy.int64'>
# source_accessed: Accessed 16 June 2015
# source_label: Eurostat
# source_link: http://bit.ly/tsdsc340
# subtitle: Gender pay gap (%) in selected Member States (2013)
# thumb: <img src="https://api.plot.ly/v2/files/gauden:519/image?image_name=block-thumb" alt="Gender pay gap in 29 countries in Europe">
# time_epoch: <type 'float'>
# time_human: <type 'str'>
# title: Gender pay gap in 29 countries in Europe
# url_embed: https://plot.ly/~gauden/519.embed
# url_svg: https://plot.ly/~gauden/519.svg
# x_label: <type 'NoneType'>
# y_label: Percentage
#
# DF: <class 'pandas.core.frame.DataFrame'>
# caption: <type 'NoneType'>
# fig: <class 'plotly.graph_objs.graph_objs.Figure'>
# fig_no: <type 'numpy.int64'>
# filename: <type 'str'>
# plot_height: <type 'numpy.int64'>
# plot_width: <type 'numpy.int64'>
# record: <type 'dict'>
# ref_no: <type 'numpy.int64'>
# source_accessed: Accessed 22 April 2015
# source_label: WHO/Europe Health for All Database
# source_link: http://data.euro.who.int/hfadb/
# subtitle: Rate per 1000, girls and boys, WHO European Region (2000-2012)
# thumb: <img src="https://api.plot.ly/v2/files/gauden:521/image?image_name=block-thumb" alt="Probability of dying before 5 years">
# time_epoch: <type 'float'>
# time_human: <type 'str'>
# title: Probability of dying before 5 years
# url_embed: https://plot.ly/~gauden/521.embed
# url_svg: https://plot.ly/~gauden/521.svg
# x_label: Year
# y_label: Probability of dying before 5 years per 1000 live births
#
# DF: <class 'pandas.core.frame.DataFrame'>
# caption: <type 'NoneType'>
# fig: <class 'plotly.graph_objs.graph_objs.Figure'>
# fig_no: <type 'numpy.int64'>
# filename: <type 'str'>
# plot_height: <type 'numpy.int64'>
# plot_width: <type 'numpy.int64'>
# record: <type 'dict'>
# ref_no: <type 'numpy.int64'>
# source_accessed: Accessed 23 June 2015
# source_label: Eurostat
# source_link: http://ec.europa.eu/eurostat/web/products-datasets/-/t2020_50
# subtitle: Risk of poverty and social exclusion for girls age less than 6 years in the EU (2013)
# thumb: <img src="https://api.plot.ly/v2/files/gauden:525/image?image_name=block-thumb" alt="Girls at risk of poverty and social exclusion">
# time_epoch: <type 'float'>
# time_human: <type 'str'>
# title: Girls at risk of poverty and social exclusion
# url_embed: https://plot.ly/~gauden/525.embed
# url_svg: https://plot.ly/~gauden/525.svg
# x_label: <type 'NoneType'>
# y_label: Percentage
#
# ¶ The former Yugoslav Republic of Macedonia (MKD is an abbreviation of the ISO).
# DF: <class 'pandas.core.frame.DataFrame'>
# caption: <type 'NoneType'>
# fig: <class 'plotly.graph_objs.graph_objs.Figure'>
# fig_no: <type 'numpy.int64'>
# filename: <type 'str'>
# plot_height: <type 'numpy.int64'>
# plot_width: <type 'numpy.int64'>
# record: <type 'dict'>
# ref_no: <type 'numpy.int64'>
# source_accessed: Accessed on 26 April 2015
# source_label: Unicef 2015 State of the World's Children  (2015)
# source_link: http://www.data.unicef.org/resources/the-state-of-the-world-s-children-report-2015-statistical-tables
# subtitle: Pre-primary School Participation for girls (2000-2012)
# thumb: <img src="https://api.plot.ly/v2/files/gauden:523/image?image_name=block-thumb" alt="Opportunity for early developments for girls">
# time_epoch: <type 'float'>
# time_human: <type 'str'>
# title: Opportunity for early developments for girls
# url_embed: https://plot.ly/~gauden/523.embed
# url_svg: https://plot.ly/~gauden/523.svg
# x_label: <type 'NoneType'>
# y_label: % of eligible population
#
# DF: <class 'pandas.core.frame.DataFrame'>
# caption: <type 'NoneType'>
# fig: <class 'plotly.graph_objs.graph_objs.Figure'>
# fig_no: <type 'numpy.int64'>
# filename: <type 'str'>
# plot_height: <type 'numpy.int64'>
# plot_width: <type 'numpy.int64'>
# record: <type 'dict'>
# ref_no: <type 'numpy.int64'>
# source_accessed: Accessed 13 July 2015
# source_label: United Nations Development Programme (UNDP)
# source_link: http://hdr.undp.org/en/content/table-4-gender-inequality-index
# subtitle: Adolescents birth rates (2010-2015) by mean years of schooling (2002-2012)
# thumb: <img src="https://api.plot.ly/v2/files/gauden:529/image?image_name=block-thumb" alt="Correlation between schooling and adolescent birth rate">
# time_epoch: <type 'float'>
# time_human: <type 'str'>
# title: Correlation between schooling and adolescent birth rate
# url_embed: https://plot.ly/~gauden/529.embed
# url_svg: https://plot.ly/~gauden/529.svg
# x_label: Mean years of schooling (female, 2002-2012)
# y_label: Births per 1,000 women aged 15-19 (2010/2015)
#
# DF: <class 'pandas.core.frame.DataFrame'>
# caption: <type 'NoneType'>
# fig: <class 'plotly.graph_objs.graph_objs.Figure'>
# fig_no: <type 'numpy.int64'>
# filename: <type 'str'>
# plot_height: <type 'numpy.int64'>
# plot_width: <type 'numpy.int64'>
# record: <type 'dict'>
# ref_no: <type 'numpy.int64'>
# source_accessed: Accessed 30 June 2015
# source_label: Global Youth Tobacco Survey (GYTS)
# source_link: http://1.usa.gov/1L02Ezu
# subtitle: Current smoked tobacco use, adolescents girls aged 13-15 years, in selected countries
# thumb: <img src="https://api.plot.ly/v2/files/gauden:527/image?image_name=block-thumb" alt="Tobacco smoking among adolescent girls">
# time_epoch: <type 'float'>
# time_human: <type 'str'>
# title: Tobacco smoking among adolescent girls
# url_embed: https://plot.ly/~gauden/527.embed
# url_svg: https://plot.ly/~gauden/527.svg
# x_label: <type 'NoneType'>
# y_label: Prevalence (%)
#
# DF: <class 'pandas.core.frame.DataFrame'>
# caption: <type 'NoneType'>
# fig: <class 'plotly.graph_objs.graph_objs.Figure'>
# fig_no: <type 'numpy.int64'>
# filename: <type 'str'>
# plot_height: <type 'numpy.int64'>
# plot_width: <type 'numpy.int64'>
# record: <type 'dict'>
# ref_no: <type 'numpy.int64'>
# source_accessed: Accessed 31 May 2015
# source_label: Unicef 2015 State of the World's Children  (2011)
# source_link: http://www.unicef.org/sowc2011/fullreport.php
# subtitle: Differences in adolescents in attitudes towards wife beating (2009-2013)
# thumb: <img src="https://api.plot.ly/v2/files/gauden:531/image?image_name=block-thumb" alt="Adolescents accepting  wife-beating ">
# time_epoch: <type 'float'>
# time_human: <type 'str'>
# title: Adolescents accepting  wife-beating
# url_embed: https://plot.ly/~gauden/531.embed
# url_svg: https://plot.ly/~gauden/531.svg
# x_label: <type 'NoneType'>
# y_label: Percentage
#
# DF: <class 'pandas.core.frame.DataFrame'>
# caption: <type 'NoneType'>
# fig: <class 'plotly.graph_objs.graph_objs.Figure'>
# fig_no: <type 'numpy.int64'>
# filename: <type 'str'>
# plot_height: <type 'numpy.int64'>
# plot_width: <type 'numpy.int64'>
# record: <type 'dict'>
# ref_no: <type 'numpy.int64'>
# source_accessed: Accessed 25 May 2015
# source_label: Eurostat
# source_link: http://ec.europa.eu/eurostat/web/products-datasets/-/hlth_silc_10
# subtitle: Self-reported health, women aged 18-44, by high and low income quintiles (2013)
# thumb: <img src="https://api.plot.ly/v2/files/gauden:533/image?image_name=block-thumb" alt="High income women in Europe report better health">
# time_epoch: <type 'float'>
# time_human: <type 'str'>
# title: High income women in Europe report better health
# url_embed: https://plot.ly/~gauden/533.embed
# url_svg: https://plot.ly/~gauden/533.svg
# x_label: <type 'NoneType'>
# y_label: Percentage reporting bad or very-bad health (%)
#
# DF: <class 'pandas.core.frame.DataFrame'>
# caption: <type 'NoneType'>
# fig: <class 'plotly.graph_objs.graph_objs.Figure'>
# fig_no: <type 'numpy.int64'>
# filename: <type 'str'>
# plot_height: <type 'numpy.int64'>
# plot_width: <type 'numpy.int64'>
# record: <type 'dict'>
# ref_no: <type 'numpy.int64'>
# source_accessed: <type 'NoneType'>
# source_label: <type 'NoneType'>
# source_link: <type 'NoneType'>
# subtitle: Maternal mortality ratio compared to the mean number of years in school, females, 2005-2012
# thumb: <img src="https://api.plot.ly/v2/files/gauden:537/image?image_name=block-thumb" alt="Risk of maternal mortality by Schooling (2005-2012)">
# time_epoch: <type 'float'>
# time_human: <type 'str'>
# title: Risk of maternal mortality by Schooling (2005-2012)
# url_embed: https://plot.ly/~gauden/537.embed
# url_svg: https://plot.ly/~gauden/537.svg
# x_label: Mean Number of Years in School (Females)
# y_label: Maternal mortality ratio (deaths per 100,000 live births), 2010
#
# DF: <class 'pandas.core.frame.DataFrame'>
# caption: <type 'NoneType'>
# fig: <class 'plotly.graph_objs.graph_objs.Figure'>
# fig_no: <type 'numpy.int64'>
# filename: <type 'str'>
# plot_height: <type 'numpy.int64'>
# plot_width: <type 'numpy.int64'>
# record: <type 'dict'>
# ref_no: <type 'numpy.int64'>
# source_accessed: Accessed 26 May 2015
# source_label: United Nations Statistics Division.
# source_link: http://bit.ly/unmet_need_fp
# subtitle: Unmet needs for family planning, total, percentage (last year available)
# thumb: <img src="https://api.plot.ly/v2/files/gauden:535/image?image_name=block-thumb" alt="Unmet needs for family planning">
# time_epoch: <type 'float'>
# time_human: <type 'str'>
# title: Unmet needs for family planning
# url_embed: https://plot.ly/~gauden/535.embed
# url_svg: https://plot.ly/~gauden/535.svg
# x_label: <type 'NoneType'>
# y_label: Percentage
#
# DF: <class 'pandas.core.frame.DataFrame'>
# caption: <type 'NoneType'>
# fig: <class 'plotly.graph_objs.graph_objs.Figure'>
# fig_no: <type 'numpy.int64'>
# filename: <type 'str'>
# plot_height: <type 'numpy.int64'>
# plot_width: <type 'numpy.int64'>
# record: <type 'dict'>
# ref_no: <type 'numpy.int64'>
# source_accessed: Accessed 25 May 2015
# source_label: Eurostat
# source_link: http://ec.europa.eu/eurostat/web/products-datasets/-/hlth_silc_10
# subtitle: Self-rated health among women aged 65+ in EU countries by wealth quintiles (2013)
# thumb: <img src="https://api.plot.ly/v2/files/gauden:543/image?image_name=block-thumb" alt="Self-perceived health by income in older women">
# time_epoch: <type 'float'>
# time_human: <type 'str'>
# title: Self-perceived health by income in older women
# url_embed: https://plot.ly/~gauden/543.embed
# url_svg: https://plot.ly/~gauden/543.svg
# x_label: Percentage
# y_label: <type 'NoneType'>
#
# DF: <class 'pandas.core.frame.DataFrame'>
# caption: <type 'NoneType'>
# fig: <class 'plotly.graph_objs.graph_objs.Figure'>
# fig_no: <type 'numpy.int64'>
# filename: <type 'str'>
# plot_height: <type 'numpy.int64'>
# plot_width: <type 'numpy.int64'>
# record: <type 'dict'>
# ref_no: <type 'numpy.int64'>
# source_accessed: Accessed 23 June 2015
# source_label: Eurostat
# source_link: http://ec.europa.eu/eurostat/web/products-datasets/-/t2020_50
# subtitle: Differences in poverty risk among older women by age (2013)
# thumb: <img src="https://api.plot.ly/v2/files/gauden:549/image?image_name=block-thumb" alt="Poverty among older women">
# time_epoch: <type 'float'>
# time_human: <type 'str'>
# title: Poverty among older women
# url_embed: https://plot.ly/~gauden/549.embed
# url_svg: https://plot.ly/~gauden/549.svg
# x_label: <type 'NoneType'>
# y_label: Percentage
#
# DF: <class 'pandas.core.frame.DataFrame'>
# caption: <type 'NoneType'>
# fig: <class 'plotly.graph_objs.graph_objs.Figure'>
# fig_no: <type 'numpy.int64'>
# filename: <type 'str'>
# plot_height: <type 'numpy.int64'>
# plot_width: <type 'numpy.int64'>
# record: <type 'dict'>
# ref_no: <type 'numpy.int64'>
# source_accessed: Accessed 09 July 2015
# source_label: European Union Agency for Fundamental Rights (FRA)
# source_link: http://fra.europa.eu/en/vaw-survey-results
# subtitle: Long-term pyschological consequences of partner violence reported by women 60+ years
# thumb: <img src="https://api.plot.ly/v2/files/gauden:547/image?image_name=block-thumb" alt="Emotional consequences of serious physical or sexual violence since the age of 15">
# time_epoch: <type 'float'>
# time_human: <type 'str'>
# title: Emotional consequences of serious physical or sexual violence since the age of 15
# url_embed: https://plot.ly/~gauden/547.embed
# url_svg: https://plot.ly/~gauden/547.svg
# x_label: <type 'NoneType'>
# y_label: Percentage of responses
# /Users/gauden/anaconda/lib/python2.7/site-packages/pandas/core/common.py:516: UnicodeWarning:
#
# Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#     <h1>Fig. 1. Gender gap in selected European countries</h1>
#     <div style="margin: 15"><img src="https://api.plot.ly/v2/files/gauden:515/image?image_name=block-thumb" alt="Gender gap in selected European countries"></div>
#     <hr>
#
#     <h1>Fig. 2. Beyond the mortality advantage</h1>
#     <div style="margin: 15"><img src="https://api.plot.ly/v2/files/gauden:511/image?image_name=block-thumb" alt="Beyond the mortality advantage"></div>
#     <hr>
#
#     <h1>Fig. 3. Female life expectancy by Gross National Income</h1>
#     <div style="margin: 15"><img src="https://api.plot.ly/v2/files/gauden:513/image?image_name=block-thumb" alt="Female life expectancy by Gross National Income"></div>
#     <hr>
#
#     <h1>Notebook notebook_03.ipynb generated no valid plot.</h1>
#     <hr>
#
#     <h1>Fig. 5. Do European countries maximize the education gain?</h1>
#     <div style="margin: 15"><img src="https://api.plot.ly/v2/files/gauden:517/image?image_name=block-thumb" alt="Do European countries maximize the education gain?"></div>
#     <hr>
#
#     <h1>Fig. 6. Gender pay gap in 29 countries in Europe</h1>
#     <div style="margin: 15"><img src="https://api.plot.ly/v2/files/gauden:519/image?image_name=block-thumb" alt="Gender pay gap in 29 countries in Europe"></div>
#     <hr>
#
#     <h1>Fig. 7. Probability of dying before 5 years</h1>
#     <div style="margin: 15"><img src="https://api.plot.ly/v2/files/gauden:521/image?image_name=block-thumb" alt="Probability of dying before 5 years"></div>
#     <hr>
#
#     <h1>Fig. 8. Girls at risk of poverty and social exclusion</h1>
#     <div style="margin: 15"><img src="https://api.plot.ly/v2/files/gauden:525/image?image_name=block-thumb" alt="Girls at risk of poverty and social exclusion"></div>
#     <hr>
#
#     <h1>Fig. 9. Opportunity for early developments for girls</h1>
#     <div style="margin: 15"><img src="https://api.plot.ly/v2/files/gauden:523/image?image_name=block-thumb" alt="Opportunity for early developments for girls"></div>
#     <hr>
#
#     <h1>Fig. 10. Correlation between schooling and adolescent birth rate</h1>
#     <div style="margin: 15"><img src="https://api.plot.ly/v2/files/gauden:529/image?image_name=block-thumb" alt="Correlation between schooling and adolescent birth rate"></div>
#     <hr>
#
#     <h1>Fig. 11. Tobacco smoking among adolescent girls</h1>
#     <div style="margin: 15"><img src="https://api.plot.ly/v2/files/gauden:527/image?image_name=block-thumb" alt="Tobacco smoking among adolescent girls"></div>
#     <hr>
#
#     <h1>Fig. 12. Adolescents accepting  wife-beating </h1>
#     <div style="margin: 15"><img src="https://api.plot.ly/v2/files/gauden:531/image?image_name=block-thumb" alt="Adolescents accepting  wife-beating "></div>
#     <hr>
#
#     <h1>Fig. 13. High income women in Europe report better health</h1>
#     <div style="margin: 15"><img src="https://api.plot.ly/v2/files/gauden:533/image?image_name=block-thumb" alt="High income women in Europe report better health"></div>
#     <hr>
#
#     <h1>Fig. 14. Risk of maternal mortality by Schooling (2005-2012)</h1>
#     <div style="margin: 15"><img src="https://api.plot.ly/v2/files/gauden:537/image?image_name=block-thumb" alt="Risk of maternal mortality by Schooling (2005-2012)"></div>
#     <hr>
#
#     <h1>Fig. 15. Unmet needs for family planning</h1>
#     <div style="margin: 15"><img src="https://api.plot.ly/v2/files/gauden:535/image?image_name=block-thumb" alt="Unmet needs for family planning"></div>
#     <hr>
#
#     <h1>Fig. 16. Self-perceived health by income in older women</h1>
#     <div style="margin: 15"><img src="https://api.plot.ly/v2/files/gauden:543/image?image_name=block-thumb" alt="Self-perceived health by income in older women"></div>
#     <hr>
#
#     <h1>Fig. 17. Poverty among older women</h1>
#     <div style="margin: 15"><img src="https://api.plot.ly/v2/files/gauden:549/image?image_name=block-thumb" alt="Poverty among older women"></div>
#     <hr>
#
#     <h1>Fig. 18. Emotional consequences of serious physical or sexual violence since the age of 15</h1>
#     <div style="margin: 15"><img src="https://api.plot.ly/v2/files/gauden:547/image?image_name=block-thumb" alt="Emotional consequences of serious physical or sexual violence since the age of 15"></div>
#     <hr>
